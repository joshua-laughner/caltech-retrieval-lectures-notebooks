# %% [markdown]
# This notebook uses `ipywidgets`, which must be able to configure the notebook for the widgets to work. Particularly if you have the kernel and Jupyter in separate environments, see [their installation documentation](https://github.com/jupyter-widgets/ipywidgets/blob/main/docs/source/user_install.md) for necessary steps to get the widgets to work properly.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
from x_retrieval_library import explore_retrievals
explore_retrievals()

# %% [markdown]
# ## Things to explore
#
# You can reset the settings with `Kernel -> Restart Kernel and Run All Cells`
#
# 1. Play around with the first three controls (number of measurements, measurement width, and measurement margin) and get a sense of how they impact the weighting functions.
#     - Hint: Look at the top and bottom of the atmosphere for margin, and make it a generously large value.
# 1. Restore the default setting, set the smoothing width to zero for now, and explore how the relationship between the \emph{a priori} uncertainty and the measurement noise affects the result and its uncertainty
# 1. Return to the defaults then set the measurement width to zero (giving near-delta-function weighting functions) then see how the smoothing width affects the result
# 1. Return to the default again, then set the number of measurements to $\sim30$, the measurement width to $\sim2$\,km, and the measurement margin to $\sim20$\,km (more like a limb sounder)
#     - Explore how the measurement noise, _a priori_ uncertainty, and smoothing parameters affect the result
#     - both in the 20-80 km region where the measurements provide information, and the top and bottom of the profile where they do not
#     - Turn the ``add noise'' button on and off, get a sense of how different levels of measurement noise affect the result
#     - Have a think about the factors affecting how one might choose the smoothing width parameter
